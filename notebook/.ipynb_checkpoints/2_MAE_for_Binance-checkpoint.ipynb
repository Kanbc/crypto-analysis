# %% [markdown]
# # Setup

# %%
import pandas as pd
import ccxt
import json
import time
from datetime import datetime
from datetime import timedelta
import plotly.offline as py
import plotly.graph_objs as go
import talib
import numpy as np
py.init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %% [markdown]
# ## Get OHLCV data from Binance

# %% [markdown]
# format ที่ได้จาก API

# %%
# [
#     [
#         1504541580000, // UTC timestamp in milliseconds, integer
#         4235.4,        // (O)pen price, float
#         4240.6,        // (H)ighest price, float
#         4230.0,        // (L)owest price, float
#         4230.7,        // (C)losing price, float
#         37.72941911    // (V)olume (in terms of the base currency), float
#     ],
#     ...
# ]

# %%
def datetimeFormat(x):
    return datetime.fromtimestamp(x/1000).strftime('%Y-%m-%d %H:%M:%S')

# %% [markdown]
# เราอยากได้ข้อมูลมาเทสย้อนหลังสัก 100 วัน แต่ API ให้เราดึงได้ทีละ 1000 candlestick ดังนั้นต้องวนลูปดึงมาต่อกันทีละนิดๆ จนครบ จะได้

# %%
binance = ccxt.binance()

# ayear_ago_milliseconds = int(round((datetime.now() - timedelta(minutes=1000)).timestamp()*1000))

# ohlcv = binance.fetch_ohlcv('BTC/USDT', '15m', since=ayear_ago_milliseconds) # minute
ohlcv = binance.fetch_ohlcv('ETH/USDT', '1h') # hour
ohlcv_df = pd.DataFrame(ohlcv,columns = ['time', 'open', 'high', 'low', 'close', 'volumn'])

# change datetime format
ohlcv_df['time'] = ohlcv_df['time'].apply(datetimeFormat)

# %%
print(len(ohlcv_df))
ohlcv_df.head()
# Out:
# 1000
#                   time     open     high      low    close      volumn
# 0  2018-06-03 04:00:00  7613.51  7652.89  7610.00  7639.89  980.033926
# 1  2018-06-03 05:00:00  7639.89  7641.90  7616.08  7631.00  682.425580
# 2  2018-06-03 06:00:00  7633.78  7648.96  7630.01  7640.03  882.002223
# 3  2018-06-03 07:00:00  7636.81  7668.52  7636.00  7660.08  936.360540
# 4  2018-06-03 08:00:00  7660.07  7676.12  7630.05  7650.59  872.077391

# %%
trace = go.Candlestick(
            x=ohlcv_df.time, 
            open=ohlcv_df.open, 
            high=ohlcv_df.high, 
            low=ohlcv_df.low, 
            close=ohlcv_df.close
        )

layout = go.Layout(xaxis = dict(rangeslider = dict(visible = True)))
data = [trace]

fig = go.Figure(data=data,layout=layout)
py.iplot(fig, filename='simple_candlestick')
# Out:
# <div id="6a6a1b0e-6e3f-4f61-9ef0-3dca3d1e73b4" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             '6a6a1b0e-6e3f-4f61-9ef0-3dca3d1e73b4',
#             [{"close": [7639.89, 7631.0, 7640.03, 7660.08, 7650.59, 7641.41, 7643.1, 7645.28, 7655.0, 7729.64, 7720.0, 7755.25, 7753.63, 7703.8, 7714.85, 7718.83, 7720.05, 7717.0, 7730.01, 7706.58, 7695.13, 7678.0, 7699.57, 7720.01, 7692.01, 7712.82, 7714.26, 7713.99, 7703.99, 7674.0, 7690.0, 7699.01, 7660.0, 7578.76, 7597.7, 7609.24, 7627.9, 7591.06, 7505.0, 7525.74, 7494.99, 7483.0, 7496.99, 7483.1, 7475.92, 7498.0, 7494.99, 7526.19, 7547.79, 7507.01, 7487.
.0, 6538.9, 6554.75, 6534.43, 6542.44, 6536.8, 6492.81, 6471.0, 6403.74, 6388.9, 6397.17, 6440.92, 6441.05, 6399.02, 6423.99, 6455.83, 6459.71, 6457.69, 6450.2, 6463.0, 6466.43, 6447.0, 6433.0, 6406.18, 6399.57, 6358.96, 6513.99, 6522.91, 6508.0, 6488.19, 6515.35, 6520.0, 6532.67, 6483.98, 6506.09, 6521.0, 6524.7, 6540.0, 6528.06, 6513.0, 6510.57, 6527.79, 6513.4, 6529.98, 6518.91, 6508.01, 6455.37, 6490.0, 6475.0, 6516.59, 6504.12, 6498.15, 6515.0, 6523.81, 6487.0, 6499.6, 6483.0, 6449.61, 6393.05, 6415.06, 6436.06, 6415.5, 6405.5, 6423.26, 6426.5, 6431.1, 6463.01, 6457.98, 6430.0, 6418.26, 6418.94, 6436.91, 6455.04, 6460.57, 6644.95, 6728.0, 6718.15, 6694.63, 6720.05, 6716.24, 6711.08, 6712.46, 6719.85, 6709.36, 6676.48, 6683.0, 6701.63, 6700.0, 6680.87, 6699.01, 6703.02, 6714.46, 6715.28, 6726.11, 6765.82, 6760.0, 6742.32, 6739.04, 6708.0, 6717.0, 6710.49, 6742.03, 6698.0, 6717.98, 6729.96, 6741.21, 6670.0, 6618.99, 6598.53, 6601.73, 6588.85, 6587.38, 6624.08, 6627.95, 6633.99, 6641.15, 6622.06, 6626.61, 6612.0, 6727.72, 6756.04, 6750.62, 6745.01, 6751.26, 6757.5, 6748.93, 6740.0, 6715.0, 6730.01, 6761.51, 6753.35, 6759.98, 6778.48, 6772.41, 6759.21, 6741.27, 6765.29, 6758.72, 6716.45, 6736.5, 6746.0, 6732.85, 6714.67, 6720.0, 6715.99, 6713.96, 6719.97, 6703.98, 6697.0, 6714.04, 6716.78, 6699.33 ...

# %% [markdown]
# > **Note that** the info from the last (current) candle may be incomplete until the candle is closed (until the next candle starts).

# %% [markdown]
# # Exponential Moving Average

# %% [markdown]
# **Ref :** http://stockcharts.com/school/doku.php?id=chart_school:technical_indicators:moving_averages

# %%
# คำนวณจากราคา closing price

# ============= SMA ==============
# Daily Closing Prices: 11,12,13,14,15,16,17

# First day of 5-day SMA: (11 + 12 + 13 + 14 + 15) / 5 = 13

# Second day of 5-day SMA: (12 + 13 + 14 + 15 + 16) / 5 = 14

# Third day of 5-day SMA: (13 + 14 + 15 + 16 + 17) / 5 = 15

# ============= EMA ==============
# Initial SMA: 10-period sum / 10 

# Multiplier: (2 / (Time periods + 1) ) = (2 / (10 + 1) ) = 0.1818 (18.18%)

# EMA: {Close - EMA(previous day)} x multiplier + EMA(previous day).

# %%
ohlcv_df['shortEMA'] = talib.EMA(ohlcv_df['close'],timeperiod=10)
ohlcv_df['longEMA'] = talib.EMA(ohlcv_df['close'],timeperiod=20)

# %%
trace = go.Candlestick(
            x=ohlcv_df.time, 
            open=ohlcv_df.open, 
            high=ohlcv_df.high, 
            low=ohlcv_df.low, 
            close=ohlcv_df.close,
            opacity = 0.3
        )

# - slDiff = shortEMA - longEMA
# - slDiffShift1 = slDiff shift 1 step
# - action : buy(1), sell(2)

# %%
ohlcv_df['slDiff'] = ohlcv_df['shortEMA'] - ohlcv_df['longEMA']
ohlcv_df['slDiffShift1'] = ohlcv_df['slDiff'].shift(1)

# %%
def EMABuyOrSell(row):
    x = row['slDiff']
    xshift1 = row['slDiffShift1']
    # buy if short > long when previous position long > short
    if (x > 0 and xshift1 < 0) :
        return 1
    # sell if short < long when previous position long < short
    if (x < 0 and xshift1 > 0) :
        return 2
    else :
        return None

# %%
ohlcv_df['action'] = ohlcv_df.apply(EMABuyOrSell, axis=1)
ohlcv_df[25:35]
# Out:
#                    time     open     high      low    close       volumn  \
# 25  2018-06-04 05:00:00  7692.01  7716.00  7688.02  7712.82   958.547435
# 26  2018-06-04 06:00:00  7712.82  7722.29  7690.00  7714.26   950.536499
# 27  2018-06-04 07:00:00  7714.26  7760.52  7701.50  7713.99  1672.132480
# 28  2018-06-04 08:00:00  7712.92  7720.43  7665.32  7703.99  1006.028366
# 29  2018-06-04 09:00:00  7704.00  7704.97  7667.39  7674.00   946.552944
# 30  2018-06-04 10:00:00  7677.97  7699.39  7673.13  7690.00   786.506792
# 31  2018-06-04 11:00:00  7688.99  7707.00  7685.00  7699.01   758.805639
# 32  2018-06-04 12:00:00  7699.00  7703.90  7608.39  7660.00  1804.227163
# 33  2018-06-04 13:00:00  7660.00  7660.01  7568.00  7578.76  2438.077191
# 34  2018-06-04 14:00:00  7578.76  7620.02  7578.74  7597.70  1222.160348
#
#        shortEMA      longEMA     slDiff  slDiffShift1  action
# 25  7704.786222  7694.233874  10.552348     10.723499     NaN
# 26  7706.508727  7696.141124  10.367603     10.552348     NaN
# 27  7707.868959  7697.841017  10.027942     10.367603     NaN
# 28  7707.163694  7698.426635   8.737059     10.027942     NaN
# 29  7701.133931  7696.100288   5.033643      8.737059     NaN
# 30  7699.109580  7695.519309   3.590271      5.033643     NaN
# 31  7699.091475  7695.851755   3.239719      3.590271     NaN
# 32  7691.983934  7692.437303  -0.453369      3.239719     2.0
# 33  7671.397764  7681.610893 -10.213129     -0.453369     NaN
# 34  7657.998171  7673.619379 -15.621209    -10.213129     NaN

# %%
all_action = []

for index,row in ohlcv_df.iterrows():
    # Buy     
    if row['action'] == 1:
        all_action.append({
            'x0': row['time'], 
            'x1': row['time'],
            'y0': 0, 
            'y1': 1, 
            'xref': 'x', 
            'yref': 'paper',
            'line': { 
              'color': '#2ecc71', 
              'width': 1
            }
        })

    # Sell
    if row['action'] == 2:
        all_action.append({
            'x0': row['time'], 
            'x1': row['time'],
            'y0': 0, 
            'y1': 1, 
            'xref': 'x', 
            'yref': 'paper',
            'line': { 
              'color': '#e74c3c', 
              'width': 1
            }
        })

# %%
trace = go.Candlestick(
            x=ohlcv_df.time, 
            open=ohlcv_df.open, 
            high=ohlcv_df.high, 
            low=ohlcv_df.low, 
            close=ohlcv_df.close,
            opacity = 0.3
        )

short_EMA_line = go.Scatter(x=ohlcv_df.time, y=ohlcv_df.shortEMA, line = dict(color='#27ae60'))
# %%
transaction = ohlcv_df[ohlcv_df['action'].notnull()]
transaction.head()
# Out:
#                     time     open     high      low    close       volumn  \
# 32   2018-06-04 12:00:00  7699.00  7703.90  7608.39  7660.00  1804.227163
# 67   2018-06-05 23:00:00  7577.09  7611.62  7533.98  7570.00  2516.224558
# 92   2018-06-07 00:00:00  7516.98  7538.67  7502.76  7517.08   909.995246
# 96   2018-06-07 04:00:00  7619.99  7699.00  7606.20  7664.99  1165.515204
# 125  2018-06-08 09:00:00  7679.36  7681.00  7646.10  7660.45  1158.123929
#
#         shortEMA      longEMA    slDiff  slDiffShift1  action
# 32   7691.983934  7692.437303 -0.453369      3.239719     2.0
# 67   7469.822098  7469.584643  0.237455    -11.454264     1.0
# 92   7590.328177  7591.547374 -1.219197      7.219505     2.0
# 96   7592.256545  7590.088447  2.168098     -6.110518     1.0
# 125  7680.029244  7681.440126 -1.410883      0.730573     2.0

# %% [markdown]
# FEE 0.1%

# %%
my_usdt = 100
my_btc = 0
my_asset_df = pd.DataFrame(columns=['time','asset'])
fee = 0 #percent

for index,trans in transaction.iterrows():
    # buy     
    if ( trans['action'] == 1 ):
        my_usdt = my_usdt*((100-fee)/100) # fee
        my_btc = my_btc + my_usdt/trans['close'] 
        my_usdt = 0 # set to zero
        my_asset_df = my_asset_df.append({'time': trans['time'], 'asset': my_btc*trans['close']}, ignore_index=True)
        
    # sell
    if ( trans['action'] == 2 ):
        my_btc = my_btc*((100-fee)/100) # fee
        my_usdt = my_usdt + my_btc*trans['close']
        my_btc = 0 # set to zero
        my_asset_df = my_asset_df.append({'time': trans['time'], 'asset': my_usdt}, ignore_index=True)

data_plot = [go.Scatter(x=my_asset_df.time, y=my_asset_df.asset)]
py.iplot(data_plot)
# Out:
# <div id="3417114d-8b80-4d11-836d-17fbb94b5574" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("3417114d-8b80-4d11-836d-17fbb94b5574", [{"x": ["2018-06-04 12:00:00", "2018-06-05 23:00:00", "2018-06-07 00:00:00", "2018-06-07 04:00:00", "2018-06-08 09:00:00", "2018-06-09 04:00:00", "2018-06-09 06:00:00", "2018-06-09 08:00:00", "2018-06-09 19:00:00", "2018-06-12 08:00:00", "2018-06-12 19:00:00", "2018-06-14 13:00:00", "2018-06-14 22:00:00", "2018-06-14 23:00:00", "2018-06-15 20:00:00", "2018-06-17 01:00:00", "2018-06-17 21:00:00", "2018-06-17 22:00:00", "2018-06-18 05:00:00", "2018-06-18 23:00:00", "2018-06-20 08:00:00", "2018-06-20 21:00:00", "2018-06-21 21:00:00", "2018-06-24 05:00:00", "2018-06-24 07:00:00", "2018-06-25 01:00:00", "2018-06-27 00:00:00", "2018-06-28 03:00:00", "2018-06-28 11:00:00", "2018-06-30 05:00:00", "2018-07-01 22:00:00", "2018-07-02 04:00:00", "2018-07-02 08:00:00", "2018-07-02 20:00:00", "2018-07-04 05:00:00", "2018-07-04 20:00:00", "2018-07-05 13:00:00", "2018-07-05 15:00:00", "2018-07-05 21:00:00", "2018-07-06 22:00:00", "2018-07-07 20:00:00", "2018-07-08 06:00:00", "2018-07-09 11:00:00", "2018-07-09 21:00:00", "2018-07-10 00:00:00", "2018-07-13 11:00:00", "2018-07-14 02:00:00", "2018-07-14 21:00:00"], "y": [100.0, 100.0, 99.30092470277411, 99.30092470277411, 99.24210842275933, 99.24210842275933, 98.56079112669084, 98.56079112669084, 97.88821719793498, 97.88821719793498, 95.95833292956013, 95.95833292956013, 94.00760492922403, 94.00760492922403, 93.68708513511719, 93.68708513511719, 93.21202769666316, 93.21202769666316, 92.73156291211619, 92.73156291211619, 92.36928608938636, 92.36928608938636, 91.82171829702872, 91.82171829702872, 90.67603426204305, 90.67603426204305, 90.83041957852218, 90.83041957852218, 90.51914929167269, 90.51914929167269, 91.5804336806015, 91.5804336806015, 90.90522200854961, 90.90522200854961, 89.3219754529932, 89.3219754529932, 87.75361834787711, 87.75361834787711, 87.12939934580544, 87.12939934580544, 86.69010327187011, 86.69010327187011, 85.89889497041352, 85.89889497041352, 85.45115456344094, 85.45115456344094, 84.50732077684299, 84.50732077684299], "type": "scatter", "uid": "202d6ed0-8847-11e8-83cd-4a0000b78430"}], {}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %% [markdown]
# ใช้ข้อมูลย้อนหลัง 70% มา train และเมื่อนำมาทำนายข้อมูลที่เหลือ 30% แล้วให้ผลดีที่สุด

# %% [markdown]
# หาจำนวน
# - best shorterm
# - best longterm

# %%
len_all = len(ohlcv_df)
train_set = ohlcv_df[0:round(0.7*len_all)]       # 70%
test_set = ohlcv_df[round(0.7*len_all):len_all]  # 30%

# %%
# sell one ฿ for market price and receive $ right now
# print(exmo.id, exmo.create_market_sell_order('BTC/USD', 1))

# limit buy BTC/EUR, you pay €2500 and receive ฿1  when the order is closed
# print(exmo.id, exmo.create_limit_buy_order('BTC/EUR', 1, 2500.00))

# pass/redefine custom exchange-specific order params: type, amount, price, flags, etc...
# kraken.create_market_buy_order('BTC/USD', 1, {'trading_agreement': 'agree'})

# %%
24*60*100/1000
# Out:
# 144.0

# %% [markdown]
# ### Get my data

# %%
with open('privatekey.json') as json_data:
    privatekey = json.load(json_data)

# %%
binance = ccxt.binance({
    'apiKey': privatekey['api_key'],
    'secret': privatekey['api_secret'],
})

json_data = binance.fetch_balance()

balances = json_data['info']['balances']
balances_df = pd.DataFrame(balances).sort_values(by=['free'],ascending=False)

# %%
balances_df[0:10]
# Out:
#    asset          free      locked
# 22   ICN   64.93500000  0.00000000
# 74   VEN   50.88000000  0.00000000
# 46   REP    2.36563200  0.00000000
# 41  IOTA  130.39548000  0.00000000
# 65   BAT    0.48500000  0.00000000
# 0    BTC    0.01291322  0.00000000
# 16  USDT    0.00868727  0.00000000
# 58   ETC    0.00304000  0.00000000
# 1    LTC    0.00027743  0.00000000
# 2    ETH    0.00006516  0.00000000

# %% [markdown]
# free คือ ส่วนที่เก็บไว้ไม่ได้ทำไรเลย lock คือส่วนที่ตั้งขายไว้อยู่แต่ยังขายไม่ได้ ถ้าจะถามว่าเรามีเหรียญทั้งหมดเท่าไหร่ ควรคิดโดนรวมทั้งสอง column
