# %% [markdown]
# # Setup

# %%
import pandas as pd
import ccxt
import json
import time
from datetime import datetime
from datetime import timedelta
import plotly.offline as py
import plotly.graph_objs as go
import talib
import numpy as np
py.init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %% [markdown]
# ## Get OHLCV data from Binance

# %% [markdown]
# format ที่ได้จาก API

# %%
# [
#     [
#         1504541580000, // UTC timestamp in milliseconds, integer
#         4235.4,        // (O)pen price, float
#         4240.6,        // (H)ighest price, float
#         4230.0,        // (L)owest price, float
#         4230.7,        // (C)losing price, float
#         37.72941911    // (V)olume (in terms of the base currency), float
#     ],
#     ...
# ]

# %%
def datetimeFormat(x):
    return datetime.fromtimestamp(x/1000).strftime('%Y-%m-%d %H:%M:%S')

# %% [markdown]
# เราอยากได้ข้อมูลมาเทสย้อนหลังสัก 100 วัน แต่ API ให้เราดึงได้ทีละ 1000 candlestick ดังนั้นต้องวนลูปดึงมาต่อกันทีละนิดๆ จนครบ จะได้

# %%
binance = ccxt.binance()

# ayear_ago_milliseconds = int(round((datetime.now() - timedelta(minutes=1000)).timestamp()*1000))

# ohlcv = binance.fetch_ohlcv('BTC/USDT', '15m', since=ayear_ago_milliseconds) # minute
ohlcv = binance.fetch_ohlcv('ETH/USDT', '1h') # hour
ohlcv_df = pd.DataFrame(ohlcv,columns = ['time', 'open', 'high', 'low', 'close', 'volumn'])

# change datetime format
ohlcv_df['time'] = ohlcv_df['time'].apply(datetimeFormat)

# %%
print(len(ohlcv_df))
ohlcv_df.head()
# Out:
# 1000
#                   time    open    high     low   close      volumn
# 0  2018-06-04 06:00:00  618.27  619.75  615.74  619.66  1353.21355
# 1  2018-06-04 07:00:00  619.66  625.47  618.50  622.54  4168.12973
# 2  2018-06-04 08:00:00  621.88  623.54  618.00  620.50  2452.48858
# 3  2018-06-04 09:00:00  620.50  620.65  614.34  615.16  2775.69669
# 4  2018-06-04 10:00:00  615.16  620.00  614.62  618.30  1415.76926

# %%
trace = go.Candlestick(
            x=ohlcv_df.time, 
            open=ohlcv_df.open, 
            high=ohlcv_df.high, 
            low=ohlcv_df.low, 
            close=ohlcv_df.close
        )

layout = go.Layout(xaxis = dict(rangeslider = dict(visible = True)))
data = [trace]

fig = go.Figure(data=data,layout=layout)
py.iplot(fig, filename='simple_candlestick')
# Out:
# <div id="690cdfee-ee1b-4581-940b-c020fbdcaf4b" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             '690cdfee-ee1b-4581-940b-c020fbdcaf4b',
# ...

# %% [markdown]
# > **Note that** the info from the last (current) candle may be incomplete until the candle is closed (until the next candle starts).

# %% [markdown]
# # Exponential Moving Average

# %% [markdown]
# **Ref :** http://stockcharts.com/school/doku.php?id=chart_school:technical_indicators:moving_averages

# %%
# คำนวณจากราคา closing price

# ============= SMA ==============
# Daily Closing Prices: 11,12,13,14,15,16,17

# First day of 5-day SMA: (11 + 12 + 13 + 14 + 15) / 5 = 13

# Second day of 5-day SMA: (12 + 13 + 14 + 15 + 16) / 5 = 14

# Third day of 5-day SMA: (13 + 14 + 15 + 16 + 17) / 5 = 15

# ============= EMA ==============
# Initial SMA: 10-period sum / 10 

# Multiplier: (2 / (Time periods + 1) ) = (2 / (10 + 1) ) = 0.1818 (18.18%)

# EMA: {Close - EMA(previous day)} x multiplier + EMA(previous day).

# %%
# best parameter from below is 5,45
ohlcv_df['shortEMA'] = talib.EMA(ohlcv_df['close'],timeperiod=5)
ohlcv_df['longEMA'] = talib.EMA(ohlcv_df['close'],timeperiod=45)

# %%
trace = go.Candlestick(
            x=ohlcv_df.time, 
            open=ohlcv_df.open, 
            high=ohlcv_df.high, 
            low=ohlcv_df.low, 
            close=ohlcv_df.close,
            opacity = 0.3
        )

short_EMA_line = go.Scatter(x=ohlcv_df.time, y=ohlcv_df.shortEMA, line = dict(color='#27ae60'))
long_EMA_line = go.Scatter(x=ohlcv_df.time, y=ohlcv_df.longEMA, line = dict(color='#2980b9'))

layout = go.Layout(xaxis = dict(rangeslider = dict(visible = True)))
data = [trace, short_EMA_line, long_EMA_line]

fig = go.Figure(data=data,layout=layout)
py.iplot(fig, filename='simple_candlestick')
# Out:
# <div id="7840abb3-4c30-4b1d-9b99-fbf509307755" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             '7840abb3-4c30-4b1d-9b99-fbf509307755',
# ...

# %% [markdown]
# # Buy & Sell

# %% [markdown]
# สร้าง column
# - slDiff = shortEMA - longEMA
# - slDiffShift1 = slDiff shift 1 step
# - action : buy(1), sell(2)

# %%
ohlcv_df['slDiff'] = ohlcv_df['shortEMA'] - ohlcv_df['longEMA']
ohlcv_df['slDiffShift1'] = ohlcv_df['slDiff'].shift(1)

# %%
def EMABuyOrSell(row):
    x = row['slDiff']
    xshift1 = row['slDiffShift1']
    # buy if short > long when previous position long > short
    if (x > 0 and xshift1 < 0) :
        return 1
    # sell if short < long when previous position long < short
    if (x < 0 and xshift1 > 0) :
        return 2
    else :
        return None

# %%
ohlcv_df['action'] = ohlcv_df.apply(EMABuyOrSell, axis=1)
ohlcv_df[25:35]
# Out:
#                    time    open    high     low   close      volumn  \
# 25  2018-06-05 07:00:00  591.02  595.92  590.59  594.93  1560.52749
# 26  2018-06-05 08:00:00  595.38  599.00  592.83  595.50  2058.71867
# 27  2018-06-05 09:00:00  595.49  596.00  577.62  579.51  8137.28590
# 28  2018-06-05 10:00:00  579.51  584.83  576.81  582.16  4842.57604
# 29  2018-06-05 11:00:00  582.17  585.55  576.08  577.23  3852.56168
# 30  2018-06-05 12:00:00  577.24  586.71  576.92  583.71  3850.46750
# 31  2018-06-05 13:00:00  583.71  588.57  581.64  588.27  3112.05872
# 32  2018-06-05 14:00:00  588.27  589.00  583.61  586.40  2390.43944
# 33  2018-06-05 15:00:00  586.75  596.20  586.37  594.01  4874.28377
# 34  2018-06-05 16:00:00  594.00  594.01  586.00  588.05  2773.61650
#
#       shortEMA  longEMA  slDiff  slDiffShift1  action
# 25  593.555294      NaN     NaN           NaN     NaN
# 26  594.203529      NaN     NaN           NaN     NaN
# 27  589.305686      NaN     NaN           NaN     NaN
# ...

# %%
all_action = []

for index,row in ohlcv_df.iterrows():
    # Buy     
    if row['action'] == 1:
        all_action.append({
            'x0': row['time'], 
            'x1': row['time'],
            'y0': 0, 
            'y1': 1, 
            'xref': 'x', 
            'yref': 'paper',
            'line': { 
              'color': '#2ecc71', 
              'width': 1
            }
        })

    # Sell
    if row['action'] == 2:
        all_action.append({
            'x0': row['time'], 
            'x1': row['time'],
            'y0': 0, 
            'y1': 1, 
            'xref': 'x', 
            'yref': 'paper',
            'line': { 
              'color': '#e74c3c', 
              'width': 1
            }
        })

# %%
trace = go.Candlestick(
            x=ohlcv_df.time, 
            open=ohlcv_df.open, 
            high=ohlcv_df.high, 
            low=ohlcv_df.low, 
            close=ohlcv_df.close,
            opacity = 0.3
        )

short_EMA_line = go.Scatter(x=ohlcv_df.time, y=ohlcv_df.shortEMA, line = dict(color='#27ae60'))
long_EMA_line = go.Scatter(x=ohlcv_df.time, y=ohlcv_df.longEMA, line = dict(color='#2980b9'))

layout = { 'yaxis': {'title': 'BTC/USDT'}, 'shapes': all_action }

data = [trace, short_EMA_line, long_EMA_line]

fig = go.Figure(data=data,layout=layout)
py.iplot(fig, filename='simple_candlestick')
# Out:
# <div id="51df0064-4c83-4a5c-93dd-28b2f9057b27" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             '51df0064-4c83-4a5c-93dd-28b2f9057b27',
# ...

# %% [markdown]
# # Backtest

# %% [markdown]
# มีเงินต้นอยู่ $100 ใช้ algo นี้ลงทุนผลจะเป็นไง

# %%
transaction = ohlcv_df[ohlcv_df['action'].notnull()]

# %%
my_usdt = 100
my_btc = 0
my_asset_df = pd.DataFrame(columns=['time','asset'])
fee = 0 #Binance FEE 0.1%

for index,trans in transaction.iterrows():
    # buy     
    if ( trans['action'] == 1 ):
        my_usdt = my_usdt*((100-fee)/100) # fee
        my_btc = my_btc + my_usdt/trans['close'] 
        my_usdt = 0 # set to zero
        my_asset_df = my_asset_df.append({'time': trans['time'], 'asset': my_btc*trans['close']}, ignore_index=True)
        
    # sell
    if ( trans['action'] == 2 ):
        my_btc = my_btc*((100-fee)/100) # fee
        my_usdt = my_usdt + my_btc*trans['close']
        my_btc = 0 # set to zero
        my_asset_df = my_asset_df.append({'time': trans['time'], 'asset': my_usdt}, ignore_index=True)

data_plot = [go.Scatter(x=my_asset_df.time, y=my_asset_df.asset)]
py.iplot(data_plot)
# Out:
# <div id="447ac391-1421-46b9-862b-faf80cabaab8" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("447ac391-1421-46b9-862b-faf80cabaab8", [{"x": ["2018-06-07 00:00:00", "2018-06-07 04:00:00", "2018-06-08 03:00:00", "2018-06-09 09:00:00", "2018-06-09 20:00:00", "2018-06-15 00:00:00", "2018-06-15 19:00:00", "2018-06-15 23:00:00", "2018-06-16 02:00:00", "2018-06-16 17:00:00", "2018-06-16 19:00:00", "2018-06-17 01:00:00", "2018-06-18 06:00:00", "2018-06-18 23:00:00", "2018-06-21 22:00:00", "2018-06-25 18:00:00", "2018-06-25 19:00:00", "2018-06-25 20:00:00", "2018-06-26 07:00:00", "2018-06-30 06:00:00", "2018-07-04 05:00:00", "2018-07-04 19:00:00", "2018-07-06 00:00:00", "2018-07-06 23:00:00", "2018-07-07 20:00:00", "2018-07-08 06:00:00", "2018-07-09 19:00:00", "2018-07-09 20:00:00", "2018-07-09 22:00:00", 
# ...

# %%
my_asset_df['asset'][len(my_asset_df)-1]/100
# Out:
# 0.9160406522764255

# %% [markdown]
# ## Optimising and Visualising Strategy Parameters

# %% [markdown]
# เราอยากได้ข้อมูลมาเทสย้อนหลังสัก 100 วัน แต่ API ให้เราดึงได้ทีละ 1000 candlestick(1 cdst = 1h) ดังนั้นต้องวนลูปดึงมาต่อกันทีละนิดๆ จนครบแล้ว save ลงไฟล์ CSV จะได้

# %%
def get100PreviousDayFromBinance(pair):
    hrday_ago = int(round((datetime.now() - timedelta(days=100)).timestamp()*1000))
    ohlcv_eth = binance.fetch_ohlcv(pair, '1h', since=hrday_ago) 
    ohlcv_eth_df = pd.DataFrame(ohlcv_eth,columns = ['time', 'open', 'high', 'low', 'close', 'volumn'])
    ohlcv_eth_df['time'] = ohlcv_eth_df['time'].apply(datetimeFormat)
    result = ohlcv_eth_df
    
    len_data = len(result)
    last_time = result['time'][len_data-1]
    next_time = int(round((datetime.strptime(last_time,'%Y-%m-%d %H:%M:%S') + timedelta(hours=1)).timestamp()*1000))
    
    while (len_data == 1000):
        ohlcv_eth = binance.fetch_ohlcv(pair, '1h', since=next_time) 
        ohlcv_eth_df = pd.DataFrame(ohlcv_eth,columns = ['time', 'open', 'high', 'low', 'close', 'volumn'])
        ohlcv_eth_df['time'] = ohlcv_eth_df['time'].apply(datetimeFormat)
        
        result = pd.concat([result, ohlcv_eth_df])
        len_data = len(ohlcv_eth_df)
        last_time = ohlcv_eth_df['time'][len_data-1]
        next_time = int(round((datetime.strptime(last_time,'%Y-%m-%d %H:%M:%S') + timedelta(hours=1)).timestamp()*1000))
    return result

# %%
get100PreviousDayFromBinance('ETH/USDT').to_csv('dataset/eth-usdt-100day.csv', index=False)

# %% [markdown]
# สำหรับ model นี้มี parameter อยู่สองอย่างคือ
# - best shorterm lags
# - best longterm lags

# %%
ohlcv_eth_df = pd.read_csv('dataset/eth-usdt-100day.csv')
ohlcv_eth_df.head()
# Out:
#                   time    open    high     low   close      volumn
# 0  2018-04-07 03:00:00  370.38  370.61  368.00  369.32  1386.52463
# 1  2018-04-07 04:00:00  369.29  370.00  368.41  369.45   700.15537
# 2  2018-04-07 05:00:00  369.45  369.89  365.25  365.32  1239.51128
# 3  2018-04-07 06:00:00  365.74  369.30  365.04  368.89  1815.93905
# 4  2018-04-07 07:00:00  368.89  370.22  368.28  370.20  1603.90296

# %% [markdown]
# ใช้ข้อมูลย้อนหลัง 70% มา train และเมื่อนำมาทำนายข้อมูลที่เหลือ 30% แล้วให้ผลดีที่สุด

# %%
len_all = len(ohlcv_eth_df)
train_set = ohlcv_eth_df[0:round(0.7*len_all)]       # 70%
test_set = ohlcv_eth_df[round(0.7*len_all):len_all]  # 30%

# %%
def getEMATransaction(dataset_df,slags,llags):
    dataset_df = dataset_df.copy()
    dataset_df['shortEMA'] = talib.EMA(dataset_df['close'],timeperiod=slags)
    dataset_df['longEMA']  = talib.EMA(dataset_df['close'],timeperiod=llags)
    dataset_df['slDiff'] = dataset_df['shortEMA'] - dataset_df['longEMA']
    dataset_df['slDiffShift1'] = dataset_df['slDiff'].shift(1)
    dataset_df['action'] = dataset_df.apply(EMABuyOrSell, axis=1)
    transaction = dataset_df[dataset_df['action'].notnull()]
    return transaction

#Binance FEE 0.1%
def assetSimulator(initial_usd,initial_btc,exchange_fee, transaction):
    usdt,btc,asset,fee = initial_usd,initial_btc,0,exchange_fee

    for index,trans in transaction.iterrows():
        # buy     
        if ( trans['action'] == 1 ):
            usdt = usdt*((100-fee)/100) # fee
            btc = btc + usdt/trans['close'] 
            usdt = 0 # set to zero
            asset = btc*trans['close']

        # sell
        if ( trans['action'] == 2 ):
            btc = btc*((100-fee)/100) # fee
            usdt = usdt + btc*trans['close']
            btc = 0 # set to zero
            asset = usdt
    return asset

def backTest(train_set,test_set,slags,llags):
    transaction_train = getEMATransaction(train_set,slags,llags)
    transaction_test = getEMATransaction(test_set,slags,llags)
    
    #Binance FEE 0.1%
    train_asset = assetSimulator(100,0,0,transaction_train)
    test_asset = assetSimulator(100,0,0,transaction_test)
            
    return [train_asset,test_asset]

# %%
train_asset, test_asset = backTest(train_set,test_set,5,45)
train_asset, test_asset
# Out:
# (156.2217858862509, 100.71213236239225)

# %% [markdown]
# สมมติฐานนะ คิดว่าค่าของ coin ในปัจจุบันขึ้นกับค่าในอดีตไม่เกิน 1 เดือน

# %%
30*24
# Out:
# 720

# %%
short_lags = np.arange(5, 610, 10)
long_lags = np.arange(5, 610, 10)
short_long = [[short,long] for short in short_lags for long in long_lags]

pnls_train = pd.DataFrame(index=long_lags,columns = short_lags)
pnls_test = pd.DataFrame(index=long_lags,columns = short_lags)

# %%
for short, long in short_long:
    train_asset, test_asset = backTest(train_set,test_set,short,long)
    pnls_train[short][long] = train_asset
    pnls_test[short][long] = test_asset
print('Finished')
# Out:
# Finished

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()

PNLs_train = pnls_train[pnls_train.columns].astype(float)
plt.subplots(figsize = (14,10))
sns.heatmap(PNLs_train,cmap='PiYG')
plt.show()

# %%
PNLs_test = pnls_test[pnls_test.columns].astype(float)
plt.subplots(figsize = (14,10))
sns.heatmap(PNLs_test,cmap='PiYG')
plt.show()

# %% [markdown]
# เอาเฉพาะที่ทำกำไร(+10%)ได้เท่านั้น

# %%
above100_train = PNLs_train[PNLs_train > 110]
above100_test = PNLs_test[PNLs_test > 100]

# %% [markdown]
# มีกำไรทั้งชุด Test และ Train โดยถ่วงน้ำหนักให้ train 30% test 70%

# %%
avg_train_test = (0.2*above100_train + 0.8*above100_test)

PNLs_avg = avg_train_test[avg_train_test.columns].astype(float)
plt.subplots(figsize = (14,10))
sns.heatmap(PNLs_avg,cmap='PiYG')
plt.show()

# %%
avg_train_test.max()[0:10]
# Out:
# 5     111.814063
# 15    107.678376
# 25    103.136388
# 35           NaN
# 45           NaN
# 55           NaN
# 65           NaN
# 75           NaN
# 85           NaN
# 95           NaN
# dtype: float64

# %% [markdown]
# จะเห็นว่าค่ามากสุดอยู่ที่ column 5 หา row จะได้

# %%
avg_train_test[5][0:10]
# Out:
# 5            NaN
# 15           NaN
# 25           NaN
# 35           NaN
# 45    111.814063
# 55           NaN
# 65    108.335068
# 75    108.596982
# 85           NaN
# 95           NaN
# Name: 5, dtype: float64

# %% [markdown]
# พารามิเตอร์ดีสุดคือ
# - short lags = 5
# - long lags = 45

# %% [markdown]
# ลองทดสอบข้างบนดู

# %% [markdown]
# # Trading Simulator

# %%
import pandas as pd
import ccxt
import json
import time
from datetime import datetime
from datetime import timedelta
import talib
import numpy as np

# %%
with open('privatekey.json') as json_data:
    privatekey = json.load(json_data)

# %%
binance = ccxt.binance({
    'apiKey': privatekey['api_key'],
    'secret': privatekey['api_secret'],
})

# %% [markdown]
# free คือ ส่วนที่เก็บไว้ไม่ได้ทำไรเลย lock คือส่วนที่ตั้งขายไว้อยู่แต่ยังขายไม่ได้ ถ้าจะถามว่าเรามีเหรียญทั้งหมดเท่าไหร่ ควรคิดโดนรวมทั้งสอง column

# %%
def datetimeFormat(x):
    return datetime.fromtimestamp(x/1000).strftime('%Y-%m-%d %H:%M:%S')

def EMABuyOrSell(row):
    x = row['slDiff']
    xshift1 = row['slDiffShift1']
    # buy if short > long when previous position long > short
    if (x > 0 and xshift1 < 0) :
        return 1
    # sell if short < long when previous position long < short
    if (x < 0 and xshift1 > 0) :
        return 2
    else :
        return None

def getEMATransaction(dataset_df,slags,llags):
    dataset_df = dataset_df.copy()
    dataset_df['shortEMA'] = talib.EMA(dataset_df['close'],timeperiod=slags)
    dataset_df['longEMA']  = talib.EMA(dataset_df['close'],timeperiod=llags)
    dataset_df['slDiff'] = dataset_df['shortEMA'] - dataset_df['longEMA']
    dataset_df['slDiffShift1'] = dataset_df['slDiff'].shift(1)
    dataset_df['action'] = dataset_df.apply(EMABuyOrSell, axis=1)
    transaction = dataset_df[dataset_df['action'].notnull()]
    return dataset_df

# %%
ohlcv = binance.fetch_ohlcv('ETH/USDT', '1h',limit=50) # hour
ohlcv_df = pd.DataFrame(ohlcv,columns = ['time', 'open', 'high', 'low', 'close', 'volumn'])
ohlcv_df['time'] = ohlcv_df['time'].apply(datetimeFormat)

# %%
def actionSimulator(ohlcv_df, slags, llags):
    df = getEMATransaction(ohlcv_df,slags,llags)
    action = df['action'][49]
    close_price_usdt = df['close'][49]
    
    json_data = binance.fetch_balance()
    balances = json_data['info']['balances']
    balances_df = pd.DataFrame(balances).sort_values(by=['free'],ascending=False)
    
    eth_free = float(balances_df[balances_df['asset'] == 'ETH']['free'])
    usdt_free = float(balances_df[balances_df['asset'] == 'USDT']['free'])
    print(eth_free,usdt_free)
    
    # buy     
    if ( action == 1 ):
        usdt = usdt_free*(99.9/100) # fee
        amount = usdt/close_price_usdt
        binance.create_limit_buy_order('ETH/USDT', amount, close_price_usdt)

    # sell
    if ( action == 2 ):
        eth = eth_free*(99.9/100) # fee
        binance.create_market_sell_order('ETH/USDT', eth)

# %%
actionSimulator(ohlcv_df,5,45)
# Out:
# 6.516e-05 0.00868727
